# %%
# Seaborn is a data visualization library in Python built on top of **-> Matplotlib <--**.
# Its main purpose is to create statistical graphics in a simple way that are both visually attractive and easy to understand.
# mathplotlib(pyplot) - seaborn

# %%
# 🔹 Features:

# Simpler syntax than Matplotlib – You can create complex graphs with less code.

# Attractive default styles – Automatically sets color palettes, background themes, etc.

# Built-in statistical plots – Such as histogram, bar plot, scatter plot, box plot, heatmap, etc.

# Easy integration with Pandas DataFrames – You can directly use column names from a DataFrame.

# Automatic summarization – Can easily calculate and display mean, median, standard deviation, etc., in plots.

# %%
# understanding about -> import matplotlib.pyplot as plt
#                         import seaborn as sns

# %%
# # import matplotlib.pyplot as plt

# matplotlib → This is Python’s most popular library for data visualization.

# pyplot → A module inside Matplotlib that provides functions to create charts (line plots, bar charts, scatter plots, etc.).

# as plt → We give it a short alias plt so we don’t have to write matplotlib.pyplot every time.

# %%
# Matplotlib = Base library for plotting (full control, more code).

# Seaborn = Built on Matplotlib, looks better, easier syntax.

# We import both because:

# Seaborn makes charts look nice.

# Matplotlib is still needed for customization (plt.show(), titles, labels, etc.).

# %%
# plots are simply visual representations of data — like charts or graphs

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0,1,2,3,4,5])
plt.show()

# %%
# A histogram is a type of plot that shows the distribution of
# numerical data — in other words, it tells you how often values fall 
# into different ranges (called bins).

# X-axis → Represents ranges (intervals) of data values.

# Y-axis → Represents the frequency (how many values fall into each range).

# It’s like a bar chart, but instead of categories, it uses value ranges.

# Helps you understand the shape of data (normal, skewed, etc.).


# Displot - distribution plot(curv plat - looks like histogram)

# %%
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")
plt.show()

# %%
# Histogram
sns.histplot([0,1,2,3,4,5])
plt.show()

# KDE plot
sns.kdeplot([0,1,2,3,4,5])
plt.show()

# %%
data = [0, 1, 2, 3, 4, 5]

sns.histplot(data, kde=True)  # Show histogram + KDE curve
plt.show()

# %%
# so , here basic diffrence 
# bar graph :-for categorical data(seprate bars)
# histogram :- for continues data,grouped into binds
# kdE Curve = smooth line showing the distribution shape of continuous data
